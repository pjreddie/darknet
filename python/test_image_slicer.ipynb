# %%
import image_slicer
from PIL import Image

# %%
s = image_slicer.slice('../data/car_plate1/frames/frame_000701.jpg', 4)

# %%
for i in range(len(s)):
    s[i].save('../data/car_plate1/slices/{}.jpg'.format(i))

# %%
s[0].image
# Out:
# <PIL.Image.Image image mode=RGB size=960x540 at 0x10FCA8C90>

# %%
s[1].image
# Out:
# <PIL.Image.Image image mode=RGB size=960x540 at 0x10FCA8C10>

# %%
#image_slicer.join(s)

# %%
import os
import cv2
import sys
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from os.path import isfile, join

# %%
pathIn = '/Users/zhenningyang/Documents/darknet/python/temp'
files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]
files.sort(key = lambda x: int(x[0:-4]))

# %%
files
# Out:
# ['0.jpg', '1.jpg', '2.jpg', '3.jpg']
